# %%
from tensorboard import notebook
log_dir = "llama-linear-layers-all-conv-Dec-01-2/runs"
notebook.start("--logdir {} --port 4001".format(log_dir))
# Out:
# Reusing TensorBoard on port 4001 (pid 148889), started 16:26:59 ago. (Use '!kill 148889' to kill it.)
#       <iframe id="tensorboard-frame-cdf0fa35f136e30b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cdf0fa35f136e30b");
#           const url = new URL("/", window.location);
#           const port = 4001;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import pandas as pd

df_orig = pd.read_csv("../data/generated_answers_peft_llama-linear-layers-all-conv-Dec-01-2_checkpoint-0.csv", sep="\t")

# %%
df_orig
# Out:
#                                         Instructions  \
# 0  Act like Bioinformatician who uses Galaxy plat...
# 1  Act like Bioinformatician who uses Galaxy plat...
# 2  Act like Bioinformatician who uses Galaxy plat...
# 3  Act like Bioinformatician who uses Galaxy plat...
# 4  Act like Bioinformatician who uses Galaxy plat...
# 5  Act like Bioinformatician who uses Galaxy plat...
#
#                                 Ground truth answers  \
# 0  welcome, @ettoremeccia instructions are in the...
# 1  hi @rrr, this tool is not available currently ...
# 2  this is where the index was sourced: index of ...
# 3  , most likely your files have 'fastq.gz' datat...
# 4  welcome, @des_b des_b: however the alignment w...
# 5  i hope i understand your question correctly. y...
#
#                                    Predicted answers  \
# 0  As a bioinformatician who uses the Galaxy plat...
# 1  As a bioinformatician, I can understand your i...
# ...

# %%
df_pred = pd.read_csv("../data/generated_answers_peft_llama-linear-layers-all-conv-Dec-01-2_checkpoint-900.csv", sep="\t")
df_pred
# Out:
#                                         Instructions  \
# 0  Act like Bioinformatician who uses Galaxy plat...
# 1  Act like Bioinformatician who uses Galaxy plat...
# 2  Act like Bioinformatician who uses Galaxy plat...
# 3  Act like Bioinformatician who uses Galaxy plat...
# 4  Act like Bioinformatician who uses Galaxy plat...
# 5  Act like Bioinformatician who uses Galaxy plat...
#
#                                 Ground truth answers  \
# 0  welcome, @ettoremeccia instructions are in the...
# 1  hi @rrr, this tool is not available currently ...
# 2  this is where the index was sourced: index of ...
# 3  , most likely your files have 'fastq.gz' datat...
# 4  welcome, @des_b des_b: however the alignment w...
# 5  i hope i understand your question correctly. y...
#
#                                    Predicted answers  \
# 0  As a bioinformatician using the Galaxy platfor...
# 1  Ah, I see! You are looking for a tool to map R...
# ...

# %%
df_merged = df_pred.copy()
df_merged
# Out:
#                                         Instructions  \
# 0  Act like Bioinformatician who uses Galaxy plat...
# 1  Act like Bioinformatician who uses Galaxy plat...
# 2  Act like Bioinformatician who uses Galaxy plat...
# 3  Act like Bioinformatician who uses Galaxy plat...
# 4  Act like Bioinformatician who uses Galaxy plat...
# 5  Act like Bioinformatician who uses Galaxy plat...
#
#                                 Ground truth answers  \
# 0  welcome, @ettoremeccia instructions are in the...
# 1  hi @rrr, this tool is not available currently ...
# 2  this is where the index was sourced: index of ...
# 3  , most likely your files have 'fastq.gz' datat...
# 4  welcome, @des_b des_b: however the alignment w...
# 5  i hope i understand your question correctly. y...
#
#                                    Predicted answers  \
# 0  As a bioinformatician using the Galaxy platfor...
# 1  Ah, I see! You are looking for a tool to map R...
# ...

# %%
df_merged["Predicted by 7 B Llama2"] = df_orig["Predicted answers"]
df_merged["Predicted by fine-tuned Llama2"] = df_pred["Predicted answers"]

# %%
df_merged
# Out:
#                                         Instructions  \
# 0  Act like Bioinformatician who uses Galaxy plat...
# 1  Act like Bioinformatician who uses Galaxy plat...
# 2  Act like Bioinformatician who uses Galaxy plat...
# 3  Act like Bioinformatician who uses Galaxy plat...
# 4  Act like Bioinformatician who uses Galaxy plat...
# 5  Act like Bioinformatician who uses Galaxy plat...
#
#                                 Ground truth answers  \
# 0  welcome, @ettoremeccia instructions are in the...
# 1  hi @rrr, this tool is not available currently ...
# 2  this is where the index was sourced: index of ...
# 3  , most likely your files have 'fastq.gz' datat...
# 4  welcome, @des_b des_b: however the alignment w...
# 5  i hope i understand your question correctly. y...
#
#                                    Predicted answers  \
# 0  As a bioinformatician using the Galaxy platfor...
# 1  Ah, I see! You are looking for a tool to map R...
# ...

# %%
df_merged = df_merged.drop(columns=["Predicted answers", "Full generated answers"])
df_merged
# Out:
#                                         Instructions  \
# 0  Act like Bioinformatician who uses Galaxy plat...
# 1  Act like Bioinformatician who uses Galaxy plat...
# 2  Act like Bioinformatician who uses Galaxy plat...
# 3  Act like Bioinformatician who uses Galaxy plat...
# 4  Act like Bioinformatician who uses Galaxy plat...
# 5  Act like Bioinformatician who uses Galaxy plat...
#
#                                 Ground truth answers  \
# 0  welcome, @ettoremeccia instructions are in the...
# 1  hi @rrr, this tool is not available currently ...
# 2  this is where the index was sourced: index of ...
# 3  , most likely your files have 'fastq.gz' datat...
# 4  welcome, @des_b des_b: however the alignment w...
# 5  i hope i understand your question correctly. y...
#
#                              Predicted by 7 B Llama2  \
# 0  As a bioinformatician who uses the Galaxy plat...
# 1  As a bioinformatician, I can understand your i...
# ...

# %%
df_merged.to_csv("../data/compare_generations_by_lama-linear-layers-all-conv-Dec-01-2_Llama2_vs_fine_tuned_Llama2.csv", sep="\t", index=None)

# %%
#generated_answers_peft_llama-linear-layers-all-conv-Dec-01-2_checkpoint-900
